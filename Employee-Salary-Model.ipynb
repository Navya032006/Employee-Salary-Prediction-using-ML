# %%
#  Employee Salary Prediction 
# 1. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
# 2. Load Data
df = pd.read_csv("data/Salary Data.csv")
df.columns = df.columns.str.strip()  # Clean any extra spaces in column names
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# 3. Drop Duplicates and Missing Values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 324 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  324 non-null    float64
#  1   Gender               324 non-null    object
#  2   Education Level      324 non-null    object
#  3   Job Title            324 non-null    object
#  4   Years of Experience  324 non-null    float64
#  5   Salary               324 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
# 4. Label Encode Categorical Columns
label_encoders = {}
for col in ['Gender', 'Education Level', 'Job Title']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# 5. Select Features and Target
X = df[['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience']]
y = df['Salary']

# %%
# 6. Scale Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 7. Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# 8. Train Linear Regression Model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 9. Model Evaluation
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 205754135.72
# R² Score: 0.89

# %%
# Save plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.7, color='royalblue')
plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Actual vs Predicted Salary")
plt.grid(True)
plt.savefig("evaluation_plot.png")
plt.show()

# %%
# 11. Save Model and Preprocessing Objects
model_data = {
    "model": model,
    "label_encoders": label_encoders,
    "scaler": scaler,
    "feature_names": X.columns.tolist()
}
joblib.dump(model_data, "salary_predictor.pkl")
# Out:
# ['salary_predictor.pkl']

# %%
# 12. Save Score and MSE to Text Files
with open("model_score.txt", "w") as f:
    f.write(str(r2))

with open("model_mse.txt", "w") as f:
    f.write(str(mse))

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: streamlit in c:\users\navya sai\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.45.1)
# Requirement already satisfied: pandas in c:\users\navya sai\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: numpy in c:\users\navya sai\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\navya sai\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: joblib in c:\users\navya sai\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: pillow in c:\users\navya sai\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\navya sai\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: packaging<25,>=20 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\navya sai\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (6.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\navya sai\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\navya sai\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\navya sai\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: jinja2 in c:\users\navya sai\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\navya sai\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\navya sai\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (1.31.0)
# Requirement already satisfied: colorama in c:\users\navya sai\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\navya sai\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\navya sai\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\navya sai\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\navya sai\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\navya sai\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\navya sai\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2025.6.15)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\navya sai\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\navya sai\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\navya sai\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\navya sai\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\navya sai\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\navya sai\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\navya sai\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\navya sai\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\navya sai\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\navya sai\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\navya sai\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\navya sai\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\navya sai\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (3.0.2)

# %%
# !streamlit run app.py
